# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': [1 if i % 2 == 0 else 0 for i in range(365)]
    }
    dia_seco = pd.DataFrame(data)
    print(dia_seco)
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])

    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar si hay registros para cada ID en el período seleccionado
    ids_con_registros = dia_seco_periodo['ID'].unique()
    ids_todos = dia_seco['ID'].unique()

    for id in ids_todos:
        if id not in ids_con_registros:
            print(f"No tiene datos en esa fecha para el ID {id}. Seleccione otra fecha.")
    
    # Filtrar solo los IDs con registros
    dia_seco_periodo = dia_seco_periodo[dia_seco_periodo['ID'].isin(ids_con_registros)]

    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    print(conteo_dias_secos)

if __name__ == "__main__":
    main()
# Out:
#     Date & Time      ID  dia_seco
# 0    2023-01-01  169484         1
# 1    2023-01-02  169485         0
# 2    2023-01-03  169484         1
# 3    2023-01-04  169485         0
# 4    2023-01-05  169484         1
# ..          ...     ...       ...
# 360  2023-12-27  169484         1
# 361  2023-12-28  169485         0
# 362  2023-12-29  169484         1
# 363  2023-12-30  169485         0
# 364  2023-12-31  169484         1
#
# [365 rows x 3 columns]
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
#    Year      ID  Count_dias_secos
# 0  2023  169484                75

# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': [1 if i % 2 == 0 else 0 for i in range(365)]
    }
    dia_seco = pd.DataFrame(data)
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])

    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar si hay registros para cada ID en el período seleccionado
    ids_todos = dia_seco['ID'].unique()
    ids_con_datos = dia_seco_periodo['ID'].unique()
    
    for id in ids_todos:
        if id not in ids_con_datos:
            print(f"No tiene datos en esa fecha para el ID {id}. Seleccione otra fecha.")
    
    # Filtrar solo los IDs con registros
    dia_seco_periodo = dia_seco_periodo[dia_seco_periodo['ID'].isin(ids_con_datos)]

    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    if not conteo_dias_secos.empty:
        print(conteo_dias_secos)
    else:
        print("No hay datos suficientes para el período seleccionado.")

if __name__ == "__main__":
    main()
# Out:
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
#    Year      ID  Count_dias_secos
# 0  2023  169484                29

# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': [1 if i % 2 == 0 else 0 for i in range(365)]
    }
    dia_seco = pd.DataFrame(data)
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])

    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar si hay registros para cada ID en el período seleccionado
    ids_todos = dia_seco['ID'].unique()
    ids_con_datos = dia_seco_periodo['ID'].unique()
    
    for id in ids_todos:
        if id not in ids_con_datos:
            print(f"No tiene datos en esa fecha para el ID {id}. Seleccione otra fecha.")
    
    # Filtrar solo los IDs con registros
    dia_seco_periodo = dia_seco_periodo[dia_seco_periodo['ID'].isin(ids_con_datos)]

    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    if not conteo_dias_secos.empty:
        print(conteo_dias_secos)
    else:
        print("No hay datos suficientes para el período seleccionado.")

if __name__ == "__main__":
    main()
# Out:
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
#    Year      ID  Count_dias_secos
# 0  2023  169484                29

# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': [1 if i % 2 == 0 else 0 for i in range(365)]
    }
    dia_seco = pd.DataFrame(data)
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])

    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar si hay registros para cada ID en el período seleccionado
    ids_todos = dia_seco['ID'].unique()
    ids_con_datos = dia_seco_periodo['ID'].value_counts()

    for id in ids_todos:
        if id not in ids_con_datos:
            print(f"No tiene datos en esa fecha para el ID {id}. Seleccione otra fecha.")
        elif ids_con_datos[id] < num_dias:
            print(f"No hay suficientes datos para el ID {id}. Registros encontrados: {ids_con_datos[id]}. Se requieren: {num_dias}.")

    # Filtrar solo los IDs con registros suficientes
    ids_suficientes = [id for id in ids_con_datos.index if ids_con_datos[id] >= num_dias]
    dia_seco_periodo = dia_seco_periodo[dia_seco_periodo['ID'].isin(ids_suficientes)]

    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    if not conteo_dias_secos.empty:
        print(conteo_dias_secos)
    else:
        print("No hay datos suficientes para el período seleccionado.")

if __name__ == "__main__":
    main()
# Out:
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
# No hay suficientes datos para el ID 169484. Registros encontrados: 75. Se requieren: 150.
# No hay suficientes datos para el ID 169485. Registros encontrados: 75. Se requieren: 150.
# No hay datos suficientes para el período seleccionado.

# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': 1  # Cambio para que toda la columna 'dia_seco' sea igual a 1
    }
    dia_seco = pd.DataFrame(data)
    print(dia_seco)
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])
    dia_seco.to_csv('C:/Users/stzor/Desktop/Junio/ICDF/prueba_dias_secos_25JUN2024.csv', index=False, sep=';')
    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar si hay registros para cada ID en el período seleccionado
    ids_todos = dia_seco['ID'].unique()
    ids_con_datos = dia_seco_periodo['ID'].value_counts()

    for id in ids_todos:
        if id not in ids_con_datos:
            print(f"No tiene datos en esa fecha para el ID {id}. Seleccione otra fecha.")
        elif ids_con_datos[id] < num_dias:
            print(f"No hay suficientes datos para el ID {id}. Registros encontrados: {ids_con_datos[id]}. Se requieren: {num_dias}.")

    # Filtrar solo los IDs con registros suficientes
    ids_suficientes = [id for id in ids_con_datos.index if ids_con_datos[id] >= num_dias]
    dia_seco_periodo = dia_seco_periodo[dia_seco_periodo['ID'].isin(ids_suficientes)]

    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    if not conteo_dias_secos.empty:
        print(conteo_dias_secos)
    else:
        print("No hay datos suficientes para el período seleccionado.")

if __name__ == "__main__":
    main()
# Out:
#     Date & Time      ID  dia_seco
# 0    2023-01-01  169484         1
# 1    2023-01-02  169485         1
# 2    2023-01-03  169484         1
# 3    2023-01-04  169485         1
# 4    2023-01-05  169484         1
# ..          ...     ...       ...
# 360  2023-12-27  169484         1
# 361  2023-12-28  169485         1
# 362  2023-12-29  169484         1
# 363  2023-12-30  169485         1
# 364  2023-12-31  169484         1
#
# [365 rows x 3 columns]
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
# No hay suficientes datos para el ID 169484. Registros encontrados: 30. Se requieren: 150.
# No hay suficientes datos para el ID 169485. Registros encontrados: 29. Se requieren: 150.
# No hay datos suficientes para el período seleccionado.

# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': 1  # Cambio para que toda la columna 'dia_seco' sea igual a 1
    }
    dia_seco = pd.DataFrame(data)
    
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])

    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar si hay suficientes registros de días secos para cada ID en el período seleccionado
    ids_todos = dia_seco['ID'].unique()

    for id in ids_todos:
        num_dias_secos = dia_seco_periodo[(dia_seco_periodo['ID'] == id) & (dia_seco_periodo['dia_seco'] == 1)].shape[0]
        if num_dias_secos < num_dias:
            print(f"No hay suficientes días secos para el ID {id}. Días secos encontrados: {num_dias_secos}. Se requieren: {num_dias}.")
        elif num_dias_secos == 0:
            print(f"No tiene datos de días secos en esa fecha para el ID {id}. Seleccione otra fecha.")

    # Filtrar solo los IDs con suficientes registros de días secos
    ids_suficientes = dia_seco_periodo['ID'].value_counts()[dia_seco_periodo['ID'].value_counts() >= num_dias].index.tolist()
    dia_seco_periodo = dia_seco_periodo[dia_seco_periodo['ID'].isin(ids_suficientes)]

    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    if not conteo_dias_secos.empty:
        print(conteo_dias_secos)
    else:
        print("No hay datos suficientes de días secos para el período seleccionado.")

if __name__ == "__main__":
    main()
# Out:
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
# No hay suficientes días secos para el ID 169484. Días secos encontrados: 75. Se requieren: 150.
# No hay suficientes días secos para el ID 169485. Días secos encontrados: 75. Se requieren: 150.
# No hay datos suficientes de días secos para el período seleccionado.

# %% [markdown]
# cambio en el script

# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': 1  # Cambio para que toda la columna 'dia_seco' sea igual a 1
    }
    dia_seco = pd.DataFrame(data)
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])

    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar y mostrar la fecha de inicio y fin para cada ID (estación meteorológica)
    ids_todos = dia_seco['ID'].unique()

    for id in ids_todos:
        datos_id = dia_seco_periodo[dia_seco_periodo['ID'] == id]
        if datos_id.empty:
            print(f"No tiene datos en esa fecha para el ID {id}. Seleccione otra fecha.")
        else:
            fecha_inicio_estacion = datos_id['Date & Time'].min().strftime('%Y-%m-%d')
            fecha_fin_estacion = datos_id['Date & Time'].max().strftime('%Y-%m-%d')
            total_registros = datos_id.shape[0]
            print(f"Para el ID {id}: Fecha de inicio: {fecha_inicio_estacion}, Fecha de fin: {fecha_fin_estacion}, Total registros encontrados: {total_registros}")

    # Filtrar solo los IDs con suficientes registros de días secos
    ids_suficientes = dia_seco_periodo['ID'].value_counts()[dia_seco_periodo['ID'].value_counts() >= num_dias].index.tolist()
    dia_seco_periodo = dia_seco_periodo[dia_seco_periodo['ID'].isin(ids_suficientes)]

    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    if not conteo_dias_secos.empty:
        print(conteo_dias_secos)
    else:
        print("No hay datos suficientes de días secos para el período seleccionado.")

if __name__ == "__main__":
    main()
# Out:
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
# Para el ID 169484: Fecha de inicio: 2023-02-04, Fecha de fin: 2023-07-02, Total registros encontrados: 75
# Para el ID 169485: Fecha de inicio: 2023-02-03, Fecha de fin: 2023-07-01, Total registros encontrados: 75
# No hay datos suficientes de días secos para el período seleccionado.

# %%
import pandas as pd
from datetime import datetime, timedelta

def main():
    # Simulación de un DataFrame de ejemplo
    data = {
        'Date & Time': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
        'ID': [169484, 169485] * 182 + [169484],  # Añadido más de un ID para ejemplo
        'dia_seco': 1  # Cambio para que toda la columna 'dia_seco' sea igual a 1
    }
    dia_seco = pd.DataFrame(data)
    dia_seco['Date & Time'] = pd.to_datetime(dia_seco['Date & Time'])

    # Mostrar opciones al usuario
    print("Seleccione el número de días:")
    print("1. 150 días")
    print("2. 120 días")
    opcion = input("Ingrese el número de la opción (1 o 2): ")

    if opcion == '1':
        num_dias = 150
    elif opcion == '2':
        num_dias = 120
    else:
        print("Opción no válida.")
        return

    # Pedir al usuario que ingrese una fecha
    fecha_str = input("Ingrese una fecha de inicio (formato YYYY-MM-DD): ")
    try:
        fecha_inicio = datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        print("Fecha no válida.")
        return

    # Filtrar el DataFrame a partir de la fecha ingresada y el número de días seleccionados
    fecha_fin = fecha_inicio + timedelta(days=num_dias - 1)
    dia_seco_periodo = dia_seco[(dia_seco['Date & Time'] >= fecha_inicio) &
                                (dia_seco['Date & Time'] <= fecha_fin)]

    # Verificar y mostrar la fecha de inicio y fin para cada ID (estación meteorológica)
    ids_todos = dia_seco['ID'].unique()

    for id in ids_todos:
        datos_id = dia_seco_periodo[dia_seco_periodo['ID'] == id]
        if datos_id.empty:
            print(f"No tiene datos en esa fecha para el ID {id}. Seleccione otra fecha.")
        else:
            fecha_inicio_estacion = datos_id['Date & Time'].min().strftime('%Y-%m-%d')
            fecha_fin_estacion = datos_id['Date & Time'].max().strftime('%Y-%m-%d')
            total_registros = datos_id.shape[0]
            print(f"Para el ID {id}: Fecha de inicio: {fecha_inicio_estacion}, Fecha de fin: {fecha_fin_estacion}, Total registros encontrados: {total_registros}")



    # Crear una columna de año
    dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year

    # Agrupar por año e ID y contar los días secos
    conteo_dias_secos = dia_seco_periodo[dia_seco_periodo['dia_seco'] == 1].groupby(['Year', 'ID']).size().reset_index(name='Count_dias_secos')

    # Mostrar el resultado
    print(conteo_dias_secos)

if __name__ == "__main__":
    main()
# Out:
# Seleccione el número de días:
# 1. 150 días
# 2. 120 días
# Para el ID 169484: Fecha de inicio: 2023-10-04, Fecha de fin: 2023-12-31, Total registros encontrados: 45
# Para el ID 169485: Fecha de inicio: 2023-10-03, Fecha de fin: 2023-12-30, Total registros encontrados: 45
#    Year      ID  Count_dias_secos
# 0  2023  169484                45
# 1  2023  169485                45
# C:\Users\stzor\AppData\Local\Temp\ipykernel_3512\1123890793.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dia_seco_periodo['Year'] = dia_seco_periodo['Date & Time'].dt.year
